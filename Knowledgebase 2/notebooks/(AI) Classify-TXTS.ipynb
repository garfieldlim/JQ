# %%
from nltk.corpus import words
nltk.download('words')
word_set = set(words.words())  # Using a set for faster lookup

def is_text_coherent(text, threshold=0.7):
    word_list = text.split()
    if not word_list:
        return False  # Avoid division by zero for empty text

    coherent_word_count = sum(word.lower() in word_set for word in word_list)
    coherence_ratio = coherent_word_count / len(word_list)
    
    return coherence_ratio >= threshold
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/garfieldgreglim/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
import os
import shutil

source_dir = "/Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_txts"
relevant_dir = "/Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant"
irrelevant_dir = "/Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant"

for filename in os.listdir(source_dir):
    if filename.endswith(".txt"):  # Check if the file is a .txt file
        file_path = os.path.join(source_dir, filename)
        
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()

        # Classify the text
        if is_text_coherent(text):
            shutil.copy(file_path, relevant_dir)
            print(f"Copied to relevant: {filename}")
        else:
            shutil.copy(file_path, irrelevant_dir)
            print(f"Copied to irrelevant: {filename}")
# Out:
# Copied to irrelevant: Copy of 04-23-19 New Schedule of Classes 1st Semester, Academic Year 2019-2020.jpg.txt
# Copied to irrelevant: Copy of 02-26-20 1st USJR_s Best Community-Based ESD Programs Competition.pdf.txt
# Copied to relevant: Copy of 8-7-20 memo nomenclature.txt
# Copied to irrelevant: Copy of 10-08-19 Notice for Meeting (enrolment sec sem sy 2019-2020).jpg.txt
# Copied to irrelevant: Copy of 7-10-23 162.jpg.txt
# Copied to irrelevant: Copy of 01-28-20 Letter to Dr. Tapanan (Free Seminar workshop).jpg.txt
# Copied to relevant: Copy of 7-10-23 172.jpg.txt
# Copied to irrelevant: Copy of Symph.pdf.txt
# Copied to irrelevant: Copy of 7-10-23 (2)182.jpg.txt
# Copied to relevant: Copy of A GUY I KNOW 2019027.jpg.txt
# Copied to relevant: Copy of CERENIMBUS 2020017.jpg.txt
# Copied to irrelevant: Copy of 10-07-19 Request for Change of Grades- Janien Egdamin.jpg.txt
# Copied to irrelevant: Copy of 2021 May 19 Need to shift approval-Gadiane.pdf.txt
# Copied to relevant: Copy of 2018 ETCHWORMS DIGITAL HAMMER INC004.jpg.txt
# Copied to irrelevant: Copy of img008.jpg.txt
# Copied to relevant: Copy of 8-3-20 Contingency-Plan Aug,2020.txt
# Copied to irrelevant: Copy of 03-09-20 CHANGE OF GRADE- OOP Felmar Ogahayon.jpg.txt
# Copied to irrelevant: Copy of 11-28-19 Request to conduct a survey on the future upskilling requirements of women in the ITBPM workforce of Cebu.jpg.txt
# Copied to irrelevant: Copy of 6-15-20  REAP EXECOM Online Learning.pdf.txt
# Copied to irrelevant: Copy of TALLECO MOA.txt
# Copied to relevant: Copy of 2018 ETCHWORMS DIGITAL HAMMER INC004020.jpg.txt
# Copied to irrelevant: Copy of ARIELUS SOFTWARE 2019020050.jpg.txt
# Copied to irrelevant: Copy of 8-13-20 memo appts addtl.txt
# Copied to irrelevant: Copy of 3-16-20  Online-VPAM-LGA068-2019-Enrolment Updates.pdf.txt
# Copied to irrelevant: Copy of 2023 LANEX CORPORATION 056.jpg.txt
# Copied to relevant: Copy of DEEPTHINKER  072.jpg.txt
# Copied to relevant: Copy of EY018.jpg.txt
# Copied to irrelevant: Copy of 03-09-20 Excuse letter of all ROTC students - 4.jpg.txt
# Copied to relevant: Copy of img011.jpg.txt
# Copied to irrelevant: Copy of 11-14-20  Online-VPAM-LGA14-Feast day of Nuestra Senora dela Salud.pdf.txt
# Copied to irrelevant: Copy of full scale 015.jpg.txt
# Copied to relevant: Copy of full scale 005.jpg.txt
# Copied to irrelevant: Copy of Immaculate Heart of Mary Academy.jpg.txt
# Copied to irrelevant: Copy of CERENIMBUS 2020017054.jpg.txt
# Copied to relevant: Copy of 11-14-23 LETTER FOR MS. PARALES DICT.jpg.txt
# Copied to irrelevant: Copy of 01-08-2020 Memo on Notice of Meeting.jpg.txt
# Copied to relevant: Copy of 09-22-2023_BMC.jpg.txt
# Copied to relevant: Copy of ARIELUS SOFTWARE 2019020049.jpg.txt
# Copied to relevant: Copy of 7-10-23 136.jpg.txt
# Copied to irrelevant: Copy of 2019 PERFORMANCE ADVANTAGE SYSTEMS007034.jpg.txt
# Copied to irrelevant: Copy of 04-03-19 Memo on Adlaw sa Pagpamalandong.jpg.txt
# Copied to relevant: Copy of GAISANO CAPITAL 2019013041.jpg.txt
# Copied to irrelevant: Copy of UNIVERSALTECH INC 2019022039.jpg.txt
# Copied to irrelevant: Copy of 7-8-23 MEMORANDUM OF UNDERSTANDING ALLIANCE SOFTWARE113.jpg.txt
# Copied to irrelevant: Copy of DATA OUTSOURCE 2020015059.jpg.txt
# Copied to relevant: Copy of noDate_NAS 2.jpg.txt
# Copied to relevant: Copy of RED TRIDENT GAMES 064.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 144.jpg.txt
# Copied to irrelevant: Copy of page 2.jpg.txt
# Copied to relevant: Copy of 02-04-20 (1)PROBABLE CANDIDATES FOR ST. EZEKIEL MORENO AWARDEES.jpg.txt
# Copied to irrelevant: Copy of p.4.jpg.txt
# Copied to irrelevant: Copy of 3-25-20 Work Suspension.jpg.txt
# Copied to relevant: Copy of 01-09-20 FOOT MARCH- MASS SPONSORSHIP IN HONOR OF SENOR STO.NINO.jpg.txt
# Copied to relevant: Copy of img010.jpg.txt
# Copied to irrelevant: Copy of 7-20-20  REAP FORTE Week 2.pdf.txt
# Copied to irrelevant: Copy of 10-02-19 request for Subject offering 2nd semester 2019-2020.jpg.txt
# Copied to relevant: Copy of 05-06-19 DOST 2019 RICE INVITATION FROM FATHER MASPARA.pdf.txt
# Copied to irrelevant: Copy of Image (36).jpg.txt
# Copied to irrelevant: Copy of St. Scholastica_s Academy.jpg.txt
# Copied to relevant: Copy of SCS-Admission-and-Retention-Policy 2023.pdf.txt
# Copied to relevant: Copy of INTERNSHIP MEMORANDUM OF AGREEMENT 2019032.jpg.txt
# Copied to relevant: Copy of CERENIMBUS 2020017055.jpg.txt
# Copied to irrelevant: Copy of FULL SCALE.txt
# Copied to relevant: Copy of full scale 004.jpg.txt
# Copied to irrelevant: Copy of full scale 014.jpg.txt
# Copied to irrelevant: Copy of 10-12-20  Online-VPAM-LGA007-Online Placement Registration-signed.pdf.txt
# Copied to irrelevant: Copy of 02-06-19 Permission for Excuse of CICCT Students (SAP Kick-Off _ Student Forum).jpg.txt
# Copied to irrelevant: Copy of 2-24-20  COVID Committee.jpg.txt
# Copied to relevant: Copy of 7-10-23 137.jpg.txt
# Copied to irrelevant: Copy of ARIELUS SOFTWARE 2019020048.jpg.txt
# Copied to relevant: Copy of Digitization in nursing informatics in collaboration with other department048.jpg.txt
# Copied to irrelevant: Copy of page 1Class Status 1st semester 2019-2020.jpg.txt
# Copied to irrelevant: Copy of 03-03-20 CICCT Departmental Examination.jpg.txt
# Copied to irrelevant: Copy of 2023 ITECHRAR 061.jpg.txt
# Copied to irrelevant: Copy of 10-27-20  memo nov 1.txt
# Copied to irrelevant: Copy of Prelim-exam-1st sem-AY-2020.pdf.txt
# Copied to irrelevant: Copy of 07-05-19 Permission for Excuse of Commerce Students.jpg.txt
# Copied to irrelevant: Copy of page 3.jpg.txt
# Copied to relevant: Copy of 7-6-20 memo LMS.txt
# Copied to relevant: Copy of 5-30-20 Work-From-Home-Policy Final Version 2-Signed.txt
# Copied to irrelevant: Copy of 05-07-19 Change of Schedule-EC PROG Summer 2019.jpg.txt
# Copied to irrelevant: Copy of 7-8-23 MEMORANDUM OF UNDERSTANDING ALLIANCE SOFTWARE112.jpg.txt
# Copied to irrelevant: Copy of UNIVERSALTECH INC 2019022038.jpg.txt
# Copied to relevant: Copy of 7-10-23 155.jpg.txt
# Copied to irrelevant: Copy of RED TRIDENT GAMES 065.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 145.jpg.txt
# Copied to irrelevant: Copy of 11-9-20 MEMO PAO POLICY(1).pdf.txt
# Copied to irrelevant: Copy of noDate_NAS 3.jpg.txt
# Copied to irrelevant: Copy of DEEPTHINKER 2019011.pdf.txt
# Copied to irrelevant: Copy of continuation of page 1.jpg.txt
# Copied to relevant: Copy of 7-10-23 173.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 163.jpg.txt
# Copied to irrelevant: Copy of 1-17-23 Faculty Attendance004.jpg.txt
# Copied to relevant: Copy of 7-10-23 (2)183.jpg.txt
# Copied to irrelevant: Copy of ARIELUS SOFTWARE 2019020.pdf.txt
# Copied to relevant: Copy of 7-8-23 MEMORANDUM OF AGREEMENT FPT SOFTWARE107.pdf.txt
# Copied to irrelevant: Copy of 02-17-20 Invitation to Fr. Alaras for the CI Days Opening Mass.jpg.txt
# Copied to irrelevant: Copy of 4-18-23 GAME JAM003.jpg.txt
# Copied to irrelevant: Copy of FERRET9 CREATIVE SOLUTIONS 2019018.pdf.txt
# Copied to irrelevant: Copy of UNIVERSALTECH INC 2019022.pdf.txt
# Copied to irrelevant: Copy of img009.jpg.txt
# Copied to relevant: Copy of 2-21-23 Second sem Exam Memo008.jpg.txt
# Copied to relevant: Copy of 10-24-20  Online-VPAM-LGA11-Mental Health Month.pdf.txt
# Copied to irrelevant: Copy of content of the memo (2).jpg.txt
# Copied to relevant: Copy of 2023 A GUY I KNOW 059.jpg.txt
# Copied to irrelevant: Copy of 02-28-20 Letter of Request for Wifi Connection (Annual Townhall Meeting _ Pres Debate 2020).pdf.txt
# Copied to irrelevant: Copy of 10-26-20 Online-VPAM-LGA12-Implementation-of-Flexi-Learning.pdf.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM073.jpg.txt
# Copied to irrelevant: Copy of 01-15-19 Colsulation and Advisorship Time Seconde Semester 2018-2019.jpg.txt
# Copied to irrelevant: Copy of 02-11-20 Memo on Election of USJ-R FAI BOT.pdf.txt
# Copied to irrelevant: Copy of 7-8-20  Online-VPAM-LGA074-2019-Enrolment for 1st Sem.pdf.txt
# Copied to relevant: Copy of 09-22-2023_CMT.jpg.txt
# Copied to irrelevant: Copy of 02-12-20 Regular General Assembly Meeting, February 24, 2020 (1).pdf.txt
# Copied to irrelevant: Copy of 7-10-23 (2)167.jpg.txt
# Copied to irrelevant: Copy of 1-10-2023-JSH-PAASCU-VISIT042.jpg.txt
# Copied to irrelevant: Copy of 2023 ASIA DITWORDS 005.jpg.txt
# Copied to irrelevant: Copy of 2018 ETCHWORMS DIGITAL HAMMER INC004021.jpg.txt
# Copied to irrelevant: Copy of 8-26-20 memo pakighimamat2020.txt
# Copied to irrelevant: Copy of arcores (2).jpg.txt
# Copied to relevant: Copy of 7-10-23 178.jpg.txt
# Copied to relevant: Copy of 6-2-20 Memo_GCQ Guidelines.txt
# Copied to relevant: Copy of full scale 016.jpg.txt
# Copied to relevant: Copy of full scale 006.jpg.txt
# Copied to relevant: Copy of 03-22-19 letter of excuse Dr. Cuizon(1).jpg.txt
# Copied to irrelevant: Copy of 008.jpg.txt
# Copied to irrelevant: Copy of 09-22-2023_RSM.jpg.txt
# Copied to irrelevant: Copy of 01-14-20 Invitation to be resource speaker for Fromulation of Graduates Attributes.jpg.txt
# Copied to irrelevant: Copy of 08-05-19 Ocean park letter.jpg.txt
# Copied to relevant: Copy of img002.jpg.txt
# Copied to irrelevant: Copy of img012.jpg.txt
# Copied to relevant: Copy of 01-14-19 Letter for Dr. Gabison as of Januray 10, 2019.jpg.txt
# Copied to irrelevant: Copy of 07-09-19 Special Class for 1st Semester 2019-2020.jpg.txt
# Copied to relevant: Copy of 02-18-20 Turnover Schedule.pdf.txt
# Copied to irrelevant: Copy of 10-23-20  award acasio.pdf.txt
# Copied to irrelevant: Copy of 3-16-20  Online-VPAM-LGA069-2019-Important Reminders-OD.pdf.txt
# Copied to irrelevant: Copy of 01-14-20 Certificate of acceptance OJT.jpg.txt
# Copied to irrelevant: Copy of 09-11-19 memo on 2019 technology updates.jpg.txt
# Copied to relevant: Copy of DEEPTHINKER  071.jpg.txt
# Copied to irrelevant: Copy of 05-16-19 Permission for excuse for accenture program the future 2019 participants.jpg.txt
# Copied to irrelevant: Copy of 08-01-19 Invitation from STUST for iPBL 2019.jpg.txt
# Copied to irrelevant: Copy of Play Therapy.jpg.txt
# Copied to irrelevant: Copy of page 1.jpg.txt
# Copied to irrelevant: Copy of img241.jpg.txt
# Copied to relevant: Copy of noDate_NAS 1.jpg.txt
# Copied to relevant: Copy of 7-10-23 147.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 157.jpg.txt
# Copied to relevant: Copy of 2023 FACULTY-ASSOCIATION-INCORPORATED-COMMISSION-ON-ELECTION082.jpg.txt
# Copied to relevant: Copy of GAISANO CAPITAL 2019013042.jpg.txt
# Copied to irrelevant: Copy of 2023 PROGRESSIFY APPS062.jpg.txt
# Copied to irrelevant: Copy of Beautitag .pdf.txt
# Copied to irrelevant: Copy of 2023 SUN ASTERISK 060.jpg.txt
# Copied to relevant: Copy of 7-10-23 135.jpg.txt
# Copied to relevant: Copy of 08-17-19 REQUEST OF COPIES OF THE PROSPECTUS OF THE NEW CURRICULAR.jpg.txt
# Copied to irrelevant: Copy of 3-16-20 Suspension April 14, 2020.jpg.txt
# Copied to irrelevant: Copy of img440.jpg.txt
# Copied to irrelevant: Copy of 03-05-19 Permission for excuse of 2nd and 3rd year Students.jpg.txt
# Copied to relevant: Copy of 03-22-19 letter of excuse Dr. Cuizon.jpg.txt
# Copied to irrelevant: Copy of 10-02-19 Requesting for School_s Financial Assistance for Funeral Services.jpg.txt
# Copied to irrelevant: Copy of 10-27-20 Memo WFH Saturday.txt
# Copied to irrelevant: Copy of 7-10-23 (2)181.jpg.txt
# Copied to relevant: Copy of 10-06-20 ReAppointment as DEAN of SCS Dept. - Gabison (August 2020 - July 2021).jpg.txt
# Copied to relevant: Copy of 7-10-23 161.jpg.txt
# Copied to relevant: Copy of 7-10-23 171.jpg.txt
# Copied to irrelevant: Copy of continuation of page 3.jpg.txt
# Copied to irrelevant: Copy of 2023 XELEQT TECHNOLOGY 057.jpg.txt
# Copied to relevant: Copy of 2-8-23 SSC WEEK SEMINAR WORKSHOP026.jpg.txt
# Copied to irrelevant: Copy of 01-10-20 Permission for Excuse of Commerce Honor Students 1st Sem 2019-2020.jpg.txt
# Copied to irrelevant: Copy of 02-14-20 Fulbright US Scholar Program for AY 2021-2022.jpg.txt
# Copied to irrelevant: Copy of 03-10-20 PRACTICUM 2ND SEM.,SY 2018-2019 - TEJANA.jpg.txt
# Copied to relevant: Copy of ARIELUS SOFTWARE 2019020.jpg.txt
# Copied to relevant: Copy of 09-27-2023_ALF.jpg.txt
# Copied to irrelevant: Copy of DEEPTHINKER 2019011.jpg.txt
# Copied to relevant: Copy of 2018 ETCHWORMS DIGITAL HAMMER INC004023.jpg.txt
# Copied to relevant: Copy of 10-23-20  award miro.pdf.txt
# Copied to relevant: Copy of 6-8-20 Guidelines visitors.txt
# Copied to relevant: Copy of JUNE 2022 INTERNSHIP003.jpg.txt
# Copied to irrelevant: Copy of 7-8-23 MEMORANDUM OF AGREEMENT FPT SOFTWARE107.jpg.txt
# Copied to irrelevant: Copy of NESO TECHNICAL 067.jpg.txt
# Copied to irrelevant: Copy of 01-16-19 Assumption of the Office of new Director IV of CHED Regional Office VII.jpg.txt
# Copied to relevant: Copy of 8-7-20 memo density.txt
# Copied to irrelevant: Copy of UNIVERSALTECH INC 2019022.jpg.txt
# Copied to irrelevant: Copy of full scale 020.jpg.txt
# Copied to irrelevant: Copy of FERRET9 CREATIVE SOLUTIONS 2019018.jpg.txt
# Copied to irrelevant: Copy of 2018 ETCHWORMS DIGITAL HAMMER .pdf.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM071.jpg.txt
# Copied to irrelevant: Copy of 8-11-20  Online-VPAM-LGA001-2020-College Orientation.pdf.txt
# Copied to relevant: Copy of 03-11-2020 Adlaw sa Pagpamalandong.jpg.txt
# Copied to irrelevant: Copy of 01-14-20 Wide Enrollment Committee.jpg.txt
# Copied to relevant: Copy of 6-18-20 LaptopLoanPolicy.txt
# Copied to irrelevant: Copy of 2023 SYMPH 058.jpg.txt
# Copied to relevant: Copy of 6-1-20 The-Virtual-USJ-R (1).txt
# Copied to relevant: Copy of 4-28-20 LICENSURE EXAMS RESCHEDULED UNDER COVID-19.pdf.txt
# Copied to irrelevant: Copy of 5-30-20 enrol 2020-21.txt
# Copied to irrelevant: Copy of img204.jpg.txt
# Copied to irrelevant: Copy of Cicct alumni home coming 2020.jpg.txt
# Copied to relevant: Copy of 03-09-20 adlaw sa pagpamalandong.jpg.txt
# Copied to irrelevant: Copy of 5-16-20  Online-VPAM-LGA070-2019-Extension of Grade Posting.pdf.txt
# Copied to irrelevant: Copy of PERMANENT TRANSFER MR. CASTRO.jpg.txt
# Copied to relevant: Copy of 010.jpg.txt
# Copied to relevant: Copy of 7-10-23 160.jpg.txt
# Copied to relevant: Copy of MALABANAN, OLIVER (Compressed Resume).txt
# Copied to relevant: Copy of 02-13-20 Faculty Application for Emergency Leave.jpg.txt
# Copied to irrelevant: Copy of 3-24-23 DOST ASTI015.jpg.txt
# Copied to irrelevant: Copy of 02-12-20 Letter from PAO about Storage rooms.jpg.txt
# Copied to irrelevant: Copy of 2018 ETCHWORMS DIGITAL HAMMER INC004022.jpg.txt
# Copied to irrelevant: Copy of 02-11-20 FAI COMELEC Resolution No. 1.pdf.txt
# Copied to irrelevant: Copy of 2023 TAKTYL STUDIOS INC. 006.jpg.txt
# Copied to relevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM070.jpg.txt
# Copied to irrelevant: Copy of CERENIMBUS 2020017.pdf.txt
# Copied to irrelevant: Copy of women inventors summit DAY 1.jpg.txt
# Copied to irrelevant: Copy of 01-08-20 Formation Programs on Liturgy.jpg.txt
# Copied to irrelevant: Copy of 10-31-20 NHEC Summit 2020 Concept Note and Program (Revised).pdf.txt
# Copied to irrelevant: Copy of FACULTY ADMIN MEETING 006.jpg.txt
# Copied to relevant: Copy of NESO TECHNICAL 066.jpg.txt
# Copied to irrelevant: Copy of Patent Search Training-Workshop.pdf.txt
# Copied to relevant: Copy of DREAMSCAPE NETWORKS 2020016.pdf.txt
# Copied to irrelevant: Copy of Memo-from-Library-Extended-Library-Hours.pdf.txt
# Copied to relevant: Copy of CERENIMBUS 2020017056.jpg.txt
# Copied to relevant: Copy of full scale 007.jpg.txt
# Copied to irrelevant: Copy of full scale 017.jpg.txt
# Copied to irrelevant: Copy of guidelines in utilization of venue for practice in the intramurals.jpg.txt
# Copied to relevant: Copy of 6-18-20 DataConnectivity.txt
# Copied to irrelevant: Copy of 7-10-23 179.jpg.txt
# Copied to relevant: Copy of 10-07-2023_JME.jpg.txt
# Copied to irrelevant: Copy of page 2 Class Status 1st semester 2019-2020.jpg.txt
# Copied to irrelevant: Copy of DEEPTHINKER  070.jpg.txt
# Copied to irrelevant: Copy of 03-10-2020 School Equipment for Sale.jpg.txt
# Copied to relevant: Copy of CERENIMBUS 2020 (1).pdf.txt
# Copied to irrelevant: Copy of MOA-USJ-R-x-Accenture (1).pdf.txt
# Copied to relevant: Copy of 1-23-20  Tuition Fee Increase 2020.jpg.txt
# Copied to irrelevant: Copy of 8-17-20 memo appts college.txt
# Copied to relevant: Copy of 9-7-20 MGCQ Guidelines September 2020.txt
# Copied to relevant: Copy of img365.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 156.jpg.txt
# Copied to relevant: Copy of 7-10-23 146.jpg.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM079.jpg.txt
# Copied to irrelevant: Copy of 02-17-20 Status Report on the Cloud-Based HR Leaves, ED Tech Training, Online Payment Facility and Faculty Attendance Monitoring System.pdf.txt
# Copied to irrelevant: Copy of GAISANO CAPITAL 2019013043.jpg.txt
# Copied to irrelevant: Copy of 03-10-20 IT 414- IT PRACTICUM II 1ST SEM.,SY 2014-2015 - GUDIO.jpg.txt
# Copied to relevant: Copy of 02-07-20 Paascu Standard on Licensure Examination Results.jpg.txt
# Copied to relevant: Copy of 07-03-19 Launching of Physicalk Fitness- Nutrition Month Celebration.jpg.txt
# Copied to irrelevant: Copy of 10-10-19 Final Examination Schedule First Sem SY 2019.jpg.txt
# Copied to relevant: Copy of 7-10-23 134.jpg.txt
# Copied to irrelevant: Copy of 02-11-20 Room to Room Vocation Campaign 2020.jpg.txt
# Copied to relevant: Copy of RED TRIDENT GAMES 063.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 143.jpg.txt
# Copied to relevant: Copy of 08-09-19 Permission to use the Comp. Lab..jpg.txt
# Copied to irrelevant: Copy of Progressify.pdf.txt
# Copied to relevant: Copy of 10-07-19 Request for Grades- Renae Mikhaela Lao Cubelo.jpg.txt
# Copied to irrelevant: Copy of 5-30-20 1. Enrolment Guidelines for AY 2020-2021 under the New Normal - Final Copy (SB Approved) (1).pdf.txt
# Copied to relevant: Copy of DREAMSCAPE NETWORKING INC 2019025.jpg.txt
# Copied to relevant: Copy of Approved Letter - Summer Overload.jpg.txt
# Copied to irrelevant: Copy of FACULTY RESEARCHES.pdf.txt
# Copied to irrelevant: Copy of NESO TECHNICAL 2019012.jpg.txt
# Copied to relevant: Copy of 7-10-23 131.jpg.txt
# Copied to irrelevant: Copy of content of the memo (1).jpg.txt
# Copied to irrelevant: Copy of 2023 COREDEV 055.jpg.txt
# Copied to relevant: Copy of FERRET9 CREATIVE SOLUTIONS 2019018025.jpg.txt
# Copied to relevant: Copy of page1.jpg.txt
# Copied to relevant: Copy of CERENIMBUS 2020017053.jpg.txt
# Copied to irrelevant: Copy of full scale 012.jpg.txt
# Copied to irrelevant: Copy of full scale 002.jpg.txt
# Copied to relevant: Copy of 6-8-20 Guidelines on re=entry.txt
# Copied to relevant: Copy of 17-22 IT Services 2019019045.jpg.txt
# Copied to relevant: Copy of 6-8-20 Re-entry of personnel and READS and Entry of Vistors June 2020-signed.txt
# Copied to irrelevant: Copy of 02-05-20 Transaction Schedule of CHED Liaison Officer.jpg.txt
# Copied to relevant: Copy of DATA OUTSOURCE 2020015061.jpg.txt
# Copied to relevant: Copy of 5-30-20 CE.txt
# Copied to irrelevant: Copy of 9-14-20  Office of Curriculum and Instruction -OCI.pdf.txt
# Copied to relevant: Copy of p.2.jpg.txt
# Copied to irrelevant: Copy of WESERV 2019023.pdf.txt
# Copied to irrelevant: Copy of MEMORANDUM OF UNDERSTANDING ALLIANCE SOFTWARE116.jpg.txt
# Copied to relevant: Copy of 08-27-19 Requesting to offer subjects for 2nd Semester 2019-2020 (1).jpg.txt
# Copied to irrelevant: Copy of arcores (1).jpg.txt
# Copied to irrelevant: Copy of 03-05-19 Permission for excuse of IT Seminars and Tours Students.jpg.txt
# Copied to relevant: Copy of img006.jpg.txt
# Copied to irrelevant: Copy of 06-09-23 LETTER-OF-COMMITMENT035.jpg.txt
# Copied to irrelevant: Copy of 03-09-20 Excuse letter of all ROTC students - 3.jpg.txt
# Copied to irrelevant: Copy of 11-26-19 Creation of ee.usjr.edu.ph (Mr. Ranoa).jpg.txt
# Copied to irrelevant: Copy of 5-29-23 LETTER FOR CAMPUS VISIT011.jpg.txt
# Copied to relevant: Copy of 3-25-20 Early Release of Employees_ Benefits (1).pdf.txt
# Copied to irrelevant: Copy of 7-10-23 138.jpg.txt
# Copied to irrelevant: Copy of Digitization in nursing informatics in collaboration with other department047.jpg.txt
# Copied to irrelevant: Copy of 02-06-19 Permission for Excuse of Commerce Students (Spotligt 2019).pdf.txt
# Copied to irrelevant: Copy of 6-8-20 Adjusment of Lunch Break.txt
# Copied to irrelevant: Copy of 06-13-19 Letter to Dr. Gregg Gabison from Main Library.jpg.txt
# Copied to relevant: Copy of Ray Business Technologies PH.pdf.txt
# Copied to relevant: Copy of UNIVERSALTECH INC 2019022037.jpg.txt
# Copied to irrelevant: Copy of 10-31-20 Formal Invitation Letter to 2020 NHEC Summit.pdf.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM075.jpg.txt
# Copied to irrelevant: Copy of 02-10-20 Academic Calendar for A.Y. 2020-2021.pdf.txt
# Copied to irrelevant: Copy of 02-13-20 letter to Fr. Alaras for an Inspirational Message.jpg.txt
# Copied to relevant: Copy of 17-22 IT Services 2019019.jpg.txt
# Copied to irrelevant: Copy of 6-27-23 Summer IPBL018.pdf.txt
# Copied to irrelevant: Copy of 02-18-20 Nominees for Leadership Awards.jpg.txt
# Copied to relevant: Copy of GAISANO CAPITAL 2019013.pdf.txt
# Copied to irrelevant: Copy of 02-11-20 Storage Rooms.jpg.txt
# Copied to irrelevant: Copy of 03-03-19 March 2019 Qualifying examinations and Application Requirements.jpg.txt
# Copied to irrelevant: Copy of 8-15-20 memo DPC.txt
# Copied to irrelevant: Copy of 10-02-19 Journal of Creative works _The Voices_.jpg.txt
# Copied to relevant: Copy of EY016.jpg.txt
# Copied to relevant: Copy of 7-10-23 165.jpg.txt
# Copied to relevant: Copy of 7-10-23 175.jpg.txt
# Copied to irrelevant: Copy of DATA OUTSOURCE 2020015.jpg.txt
# Copied to irrelevant: Copy of 3-11-20 Report 2020.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 129.jpg.txt
# Copied to relevant: Copy of 7-10-23 139.jpg.txt
# Copied to irrelevant: Copy of Image (60).jpg.txt
# Copied to irrelevant: Copy of Image (61).jpg.txt
# Copied to irrelevant: Copy of Digitization in nursing informatics in collaboration with other department046.jpg.txt
# Copied to relevant: Copy of 7-10-23 (2)170.jpg.txt
# Copied to irrelevant: Copy of 10-12-20  Online-VPAM-LGA008-Mental Health AwarenessMonth.pdf.txt
# Copied to relevant: Copy of 7-10-23 180.jpg.txt
# Copied to irrelevant: Copy of 3-24-23 DOST ASTI011.jpg.txt
# Copied to irrelevant: Copy of summer enrolment 2019(1).jpg.txt
# Copied to relevant: Copy of 2023 TALLECO 064.jpg.txt
# Copied to relevant: Copy of UNIVERSALTECH INC 2019022036.jpg.txt
# Copied to irrelevant: Copy of 2-14-23 FAI-COMMISSION-ON-ELECTION086.jpg.txt
# Copied to irrelevant: Copy of 9-28-20  Online-VPAM-LGA005-2020-Extension of Grade Posting.pdf.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM074.jpg.txt
# Copied to irrelevant: Copy of DOST ASTI.pdf.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM080.jpg.txt
# Copied to relevant: Copy of EY017.jpg.txt
# Copied to relevant: Copy of 11-9-20  PAO POLICY1.txt
# Copied to irrelevant: Copy of 06-13-19 Letter to Fr. Ocheda about the CICCT Team building at Bacold on June 15-16,2019.jpg.txt
# Copied to irrelevant: Copy of 01-14-19 Letter for Reverend Father Maspara as of (December 13, 2019).jpg.txt
# Copied to irrelevant: Copy of REPRESENTATIVE FOR FACE IT003.pdf.txt
# Copied to irrelevant: Copy of Recommendation Letter_ Gadiane _ Seldura.pdf.txt
# Copied to irrelevant: Copy of 07-05-19 CAS Convocation.jpg.txt
# Copied to relevant: Copy of 8-3-20 GCQ Guidelines Aug2020.txt
# Copied to relevant: Copy of 7-10-23 174.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 164.jpg.txt
# Copied to relevant: Copy of 7-10-23 (2)184.jpg.txt
# Copied to relevant: Copy of 004.jpg.txt
# Copied to irrelevant: Copy of Cicct alumni home coming 2020 - Page 2.jpg.txt
# Copied to irrelevant: Copy of 3-15-23  Permission for Excuse001.jpg.txt
# Copied to irrelevant: Copy of 02-28-20 SSC COMELEC 39th Congress.pdf.txt
# Copied to irrelevant: Copy of 02-06-20 Seminar Workshop on Mobile Development for Invited Senior High School Students from Different School.jpg.txt
# Copied to relevant: Copy of MATA TECHNOLOGIES.jpg.txt
# Copied to relevant: Copy of Josenian-Mental-Health-Awareness-Month-2020-Approved-Letter.pdf.txt
# Copied to irrelevant: Copy of 1-22-20  USJ-R Trademark 2020.jpg.txt
# Copied to relevant: Copy of page 4.jpg.txt
# Copied to relevant: Copy of 7-10-23 142.jpg.txt
# Copied to relevant: Copy of 7-10-23 130.jpg.txt
# Copied to irrelevant: Copy of DEEPTHINKER 2019 (1).pdf.txt
# Copied to relevant: Copy of 2019 PERFORMANCE ADVANTAGE SYSTEMS007032.jpg.txt
# Copied to relevant: Copy of 08-29-19 Invitation to Help in Endorsing DPE and DPEC Programs.pdf.txt
# Copied to relevant: Copy of 6-18-20 memo policy laptop dta allow.txt
# Copied to relevant: Copy of WESERV 2019023027.jpg.txt
# Copied to relevant: Copy of 02-13-20 EXCUSE OF CICCT STUDENTS.jpg.txt
# Copied to relevant: Copy of 8-7-20 memo appts lay.txt
# Copied to relevant: Copy of DATA OUTSOURCE 2020015060.jpg.txt
# Copied to irrelevant: Copy of 03-09-20 2. Selected Students to attend an USA Fair.jpg.txt
# Copied to irrelevant: Copy of page 5 Class Status 1st semester 2019-2020.jpg.txt
# Copied to relevant: Copy of FERRET9 CREATIVE SOLUTIONS 2019018024.jpg.txt
# Copied to irrelevant: Copy of full scale 003.jpg.txt
# Copied to irrelevant: Copy of 5-15-23 Carles005.jpg.txt
# Copied to irrelevant: Copy of full scale 013.jpg.txt
# Copied to relevant: Copy of CERENIMBUS 2020017052.jpg.txt
# Copied to irrelevant: Copy of 6-1-20 cover-memo-The-Virtual-USJ-R - SIGNED.txt
# Copied to irrelevant: Copy of 09-07-19 Midterm exam schedule 1st sem 2019-2020.jpg.txt
# Copied to irrelevant: Copy of MEMORANDUM OF UNDERSTANDING ALLIANCE SOFTWARE117.jpg.txt
# Copied to irrelevant: Copy of p.3.jpg.txt
# Copied to irrelevant: Copy of 01-10-20 Memorandum Of Agreement.pdf.txt
# Copied to irrelevant: Copy of 6-3-23 CEBU EDUCATIONAL TOUR FOR EASTERN VISAYAS STATE UNIV022.pdf.txt
# Copied to relevant: Copy of 4-14-23 Request to use 312 for Basic Amadeus Seminar Workshop001.pdf.txt
# Copied to relevant: Copy of img007.jpg.txt
# Copied to irrelevant: Copy of 02-12-20 Ash Wednesday schedule 2020.jpg.txt
# Copied to irrelevant: Copy of 2019 PERFORMANCE ADVANTAGE SYSTEMS007.pdf.txt
# Copied to irrelevant: Copy of OVERLOAD OF SCS FACULTY MEMBERS033.jpg.txt
# Copied to relevant: Copy of 02-20-20 permission to conduct an interview from BEED Major in GEN ED Students.jpg.txt
# Copied to irrelevant: Copy of page 3 Class Status 1st semester 2019-2020.jpg.txt
# Copied to irrelevant: Copy of 08-01-19 Arrival Information.jpg.txt
# Copied to relevant: Copy of 04-04-19 Permission to Use Specific Offerings for some Blocks (DSSP).jpg.txt
# Copied to irrelevant: Copy of 09-22-2023_KDR.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 159.jpg.txt
# Copied to irrelevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM076.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 149.jpg.txt
# Copied to irrelevant: Copy of 2-14-23 FAI-COMMISSION-ON-ELECTION084.jpg.txt
# Copied to irrelevant: Copy of 2.jpg.txt
# Copied to irrelevant: Copy of 01-07-19 Change of faculty load (adding pf petition class and dissolution of low densitty subjects.jpg.txt
# Copied to irrelevant: Copy of 03-09-20 Excuse letter of all ROTC students - 12.jpg.txt
# Copied to irrelevant: Copy of 6-10-20  Online-VPAM-LGA072-2019-LMS for SUMMER 2020.pdf.txt
# Copied to relevant: Copy of 3-24-23 DOST ASTI013.jpg.txt
# Copied to irrelevant: Copy of DAY 2.jpg.txt
# Copied to relevant: Copy of 7-8-23 MEMORANDUM OF AGREEMENT FPT SOFTWARE110.jpg.txt
# Copied to relevant: Copy of 1-24-2020 Fora discussing relevant issues and concerns about the student_s researches.jpg.txt
# Copied to irrelevant: Copy of summer enrolment 2019.jpg.txt
# Copied to relevant: Copy of 7-10-23 176.jpg.txt
# Copied to relevant: Copy of continuation of page 4.jpg.txt
# Copied to relevant: Copy of 06-09-23 LETTER-OF-INTENT037.pdf.txt
# Copied to irrelevant: Copy of full scale 008.jpg.txt
# Copied to relevant: Copy of RED TRIDENT GAMES 2019014.jpg.txt
# Copied to relevant: Copy of 5-21-20 University_s ECQ Guidlines.txt
# Copied to irrelevant: Copy of 006.jpg.txt
# Copied to relevant: Copy of 8-3-20 memo CAL needs analysis.txt
# Copied to relevant: Copy of EY015.jpg.txt
# Copied to relevant: Copy of DGV SMARTSTART 2019026.jpg.txt
# Copied to relevant: Copy of CITY GOVERNMENT 2019024.jpg.txt
# Copied to irrelevant: Copy of 4-18-23 PERMISSION FOR EXCUSE OF THE INTERNATIONAL STUDIES AND POLITICAL SCIENCE STUDENTS002.jpg.txt
# Copied to irrelevant: Copy of 05-17-19 Request for Permission of CNU graduation by Mrs. Lorna Miro.jpg.txt
# Copied to relevant: Copy of 7-10-23 132.jpg.txt
# Copied to relevant: Copy of 7-8-23 MEMORANDUM OF AGREEMENT FPT SOFTWARE109.jpg.txt
# Copied to irrelevant: Copy of 3-11-2020 a COMPARATIVE STUDY Dean Listers and Non dean listers.jpg.txt
# Copied to irrelevant: Copy of GENII HUT TECHNOLOGIES CORP 2019029.jpg.txt
# Copied to irrelevant: Copy of 4-18-23 SCS DAYS EXCUSE LETTER001.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 140.jpg.txt
# Copied to irrelevant: Copy of 1-11-2023-ENDORSEMENT-OF-MEMBERS-OF-ADELANTE-LMS-TEAM-FOR-2ND-SEMESTER-2022-2023043.jpg.txt
# Copied to relevant: Copy of 2019 PERFORMANCE ADVANTAGE SYSTEMS007.jpg.txt
# Copied to relevant: Copy of 8-4-20 Contingency-Plan Aug4.pdf.txt
# Copied to irrelevant: Copy of img005.jpg.txt
# Copied to irrelevant: Copy of 03-09-20 1.Selected Students to attend an USA Fair.jpg.txt
# Copied to irrelevant: Copy of 7-10-19 Extendus 1 Internet Service.jpg.txt
# Copied to irrelevant: Copy of p.1.jpg.txt
# Copied to relevant: Copy of MEMORANDUM OF UNDERSTANDING ALLIANCE SOFTWARE115.jpg.txt
# Copied to irrelevant: Copy of 05-17-19 ANNUAL  AUGUSTINIAN RECOLLECT SPIRITUAL EXERCISE (May 11, 2019).pdf.txt
# Copied to relevant: Copy of 03-10-2020 Garage Sale (March 28,2020).jpg.txt
# Copied to irrelevant: Copy of 01-07-19 Change of faculty load (adding pf petition class and dissolution of low densitty subjects(1).jpg.txt
# Copied to irrelevant: Copy of fujitsu_endorsement_2019.pdf.txt
# Copied to irrelevant: Copy of DATA OUTSOURCE 2020015062.jpg.txt
# Copied to relevant: Copy of 17-22 IT Services 2019019046.jpg.txt
# Copied to irrelevant: Copy of page2.jpg.txt
# Copied to irrelevant: Copy of full scale 011.jpg.txt
# Copied to relevant: Copy of 1_1 INTERNET 2019031.jpg.txt
# Copied to relevant: Copy of full scale 001.jpg.txt
# Copied to irrelevant: Copy of FERRET9 CREATIVE SOLUTIONS 2019018026.jpg.txt
# Copied to irrelevant: Copy of 9-11-20  Prelim-exam-1st sem-AY-2020.pdf.txt
# Copied to irrelevant: Copy of 11-14-23 LETTER FOR MS. PARALES DICT (3).jpg.txt
# Copied to relevant: Copy of 11-14-23 LETTER FOR MS. PARALES DICT (2).jpg.txt
# Copied to irrelevant: Copy of 02-06-20 Official Subject Evaluation.jpg.txt
# Copied to irrelevant: Copy of 02-17-20 Invitation to Fr. Sia for CICCT Alumni 2020.pdf.txt
# Copied to relevant: Copy of 7-8-23 MEMORANDUM OF AGREEMENT FPT SOFTWARE108.jpg.txt
# Copied to irrelevant: Copy of 8-10-20 memo terminology.txt
# Copied to relevant: Copy of 07-09-19 Lecture Forum on the State of the Nation Address.jpg.txt
# Copied to irrelevant: Copy of Provisional Program.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 133.jpg.txt
# Copied to relevant: Copy of 2019 PERFORMANCE ADVANTAGE SYSTEMS007031.jpg.txt
# Copied to irrelevant: Copy of 10-12-20  Online-VPAM-LGA10-Feedbacking Faculty Ranking.pdf.txt
# Copied to irrelevant: Copy of 7-10-23 141.jpg.txt
# Copied to relevant: Copy of 09-25-2023_MLDM.jpg.txt
# Copied to irrelevant: Copy of GAISANO CAPITAL 2019013044.jpg.txt
# Copied to irrelevant: Copy of TALLECO MOA.pdf.txt
# Copied to irrelevant: Copy of NESO TECHNICAL 068.jpg.txt
# Copied to irrelevant: Copy of img121.jpg.txt
# Copied to irrelevant: Copy of 6-3-23 CEBU EDUCATIONAL TOUR FOR EASTERN VISAYAS STATE UNIV023.jpg.txt
# Copied to irrelevant: Copy of WESERV 2019023.jpg.txt
# Copied to irrelevant: Copy of 02-12-20 Letter to hold classes for summer 2020.jpg.txt
# Copied to irrelevant: Copy of 6-7-23 International Project-Based Learning Program (IPBL) 004.jpg.txt
# Copied to irrelevant: Copy of Solicitation Letter - Christmas 2019.pdf.txt
# Copied to irrelevant: Copy of 03-09-20 Excuse letter of all ROTC students - 1.jpg.txt
# Copied to relevant: Copy of DREAMSCAPE NETWORKING INC 2019025(1).jpg.txt
# Copied to relevant: Copy of 09-22-2023_VFP.jpg.txt
# Copied to relevant: Copy of img004.jpg.txt
# Copied to irrelevant: Copy of 08-27-19 Requesting to offer subjects for 2nd Semester 2019-2020.jpg.txt
# Copied to irrelevant: Copy of 1-27-20  COPE Sample SchemeTemplate.pdf.txt
# Copied to irrelevant: Copy of full scale 010.jpg.txt
# Copied to irrelevant: Copy of Invitation Letter.jpg.txt
# Copied to relevant: Copy of ADELANTE LMS022.jpg.txt
# Copied to relevant: Copy of CERENIMBUS 2020017051.jpg.txt
# Copied to relevant: Copy of front page.jpg.txt
# Copied to irrelevant: Copy of 08-01-19 Permission to Excuse STUST ipBL Participants-page0001.jpg.txt
# Copied to irrelevant: Copy of 17-22 IT Services 2019019047.jpg.txt
# Copied to relevant: Copy of NESO TECHNICAL 2019012.pdf.txt
# Copied to relevant: Copy of 09-26-2023_RAMS.jpg.txt
# Copied to relevant: Copy of 10-06-20 ReAppointment as IT Administrator - Gabison (August 2020 - July 2021).jpg.txt
# Copied to relevant: Copy of 9-1-20 memo HolySpirit 2020.txt
# Copied to irrelevant: Copy of 02-12-20 Research Congress_ Sustainable Communities through Education, Research and Innovation.pdf.txt
# Copied to irrelevant: Copy of 06-26-23 iPBL013.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 148.jpg.txt
# Copied to relevant: Copy of 2023 MARSHALL-MCLUHAN-FORUM077.jpg.txt
# Copied to irrelevant: Copy of 7-10-23 158.jpg.txt
# Copied to relevant: Copy of GAISANO CAPITAL 2019013.jpg.txt
# Copied to relevant: Copy of UNIVERSALTECH INC 2019022035.jpg.txt
# Copied to relevant: Copy of MOA-Passerelles-Numeriques-Philippines.pdf.txt
# Copied to irrelevant: Copy of Sportsfest and Intramurals 2019.jpg.txt
# Copied to irrelevant: Copy of 2-14-23 FAI-COMMISSION-ON-ELECTION085.jpg.txt
# Copied to irrelevant: Copy of 10-28-19  Borrowing of BRD1.jpg.txt
# Copied to irrelevant: Copy of 01-10-20 Full Project Proposal for the Center of Excellence in IT Education in Region VII for SY 2018-2020.pdf.txt
# Copied to irrelevant: Copy of 10-07-19  Request for Change of Grades- Jihrey Pingol.jpg.txt
# Copied to irrelevant: Copy of acceptance.txt
# Copied to relevant: Copy of 3-24-23 DOST ASTI012.jpg.txt
# Copied to irrelevant: Copy of 02-03-20 Annual Performance Appraisal of Office Personnel or Staff.jpg.txt
# Copied to irrelevant: Copy of MICAB SYSTEM CORP 2019030.jpg.txt
# Copied to irrelevant: Copy of 7-8-23 MEMORANDUM OF AGREEMENT FPT SOFTWARE111.jpg.txt
# Copied to irrelevant: Copy of DATA OUTSOURCE 2020015.pdf.txt
# Copied to irrelevant: Copy of Digitization in nursing informatics in collaboration with other department045.jpg.txt
# Copied to relevant: Copy of full scale 019.jpg.txt
# Copied to relevant: Copy of 8-3-20 LOG.txt
# Copied to irrelevant: Copy of full scale 009.jpg.txt
# Copied to irrelevant: Copy of 1-27-20  PAASCU Engineering.jpg.txt
# Copied to relevant: Copy of 9-10-20  Online-VPAM-LGA02-2020-Holy Spirit Mass.pdf.txt
# Copied to relevant: Copy of 11-13-20 Significant Religious Events.pdf.txt
# Copied to irrelevant: Copy of 10-23-20  award bandalan.pdf.txt
# Copied to relevant: Copy of 7-10-23 177.jpg.txt
# Copied to relevant: Copy of ALLIANCE.pdf.txt
# Copied to relevant: Copy of 10-31-20 CEAP-NHEC Invitation to 2020 NHEC Summit 1.png.txt
# Copied to irrelevant: Copy of 03-09-20 Excuse letter of all ROTC students - 8.jpg.txt
# Copied to relevant: Copy of 8-26-20 PAKIGHIMAMAT-202O-Program.pdf.txt
# Copied to relevant: Copy of 2-21-23 PreLim Exam Memo008.jpg.txt
# Copied to irrelevant: Copy of 17-22 IT Services 2019019.pdf.txt

# %%
import os

def delete_small_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):  # Check if the file is a .txt file
            file_path = os.path.join(directory, filename)
            
            with open(file_path, 'r', encoding='utf-8') as file:
                text = file.read()
                word_count = len(text.split())

            if word_count < 50:
                os.remove(file_path)
                print(f"Deleted {filename} from {directory}")

# Directories
relevant_dir = "/Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant"
irrelevant_dir = "/Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant"

# Delete small files from both directories
delete_small_files(relevant_dir)
delete_small_files(irrelevant_dir)
# Out:
# Deleted Copy of 7-10-23 136.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 01-09-20 FOOT MARCH- MASS SPONSORSHIP IN HONOR OF SENOR STO.NINO.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 05-06-19 DOST 2019 RICE INVITATION FROM FATHER MASPARA.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of CERENIMBUS 2020017055.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 7-10-23 178.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of full scale 016.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 7-10-23 161.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of JUNE 2022 INTERNSHIP003.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 4-28-20 LICENSURE EXAMS RESCHEDULED UNDER COVID-19.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of DATA OUTSOURCE 2020015061.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 08-27-19 Requesting to offer subjects for 2nd Semester 2019-2020 (1).jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 7-10-23 175.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of EY017.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 7-10-23 (2)184.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of page 4.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of CERENIMBUS 2020017052.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 1-24-2020 Fora discussing relevant issues and concerns about the student_s researches.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 7-10-23 176.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of EY015.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 17-22 IT Services 2019019046.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 2019 PERFORMANCE ADVANTAGE SYSTEMS007031.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of ADELANTE LMS022.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of front page.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 09-26-2023_RAMS.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 2023 MARSHALL-MCLUHAN-FORUM077.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of full scale 019.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/relevant
# Deleted Copy of 03-09-20 CHANGE OF GRADE- OOP Felmar Ogahayon.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of Immaculate Heart of Mary Academy.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of p.4.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 02-06-19 Permission for Excuse of CICCT Students (SAP Kick-Off _ Student Forum).jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of UNIVERSALTECH INC 2019022038.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of continuation of page 1.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of UNIVERSALTECH INC 2019022.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of img009.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 7-8-20  Online-VPAM-LGA074-2019-Enrolment for 1st Sem.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 2018 ETCHWORMS DIGITAL HAMMER INC004021.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 008.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 09-22-2023_RSM.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 01-16-19 Assumption of the Office of new Director IV of CHED Regional Office VII.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 5-16-20  Online-VPAM-LGA070-2019-Extension of Grade Posting.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of CERENIMBUS 2020017.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of full scale 017.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 7-10-23 156.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 2023 MARSHALL-MCLUHAN-FORUM079.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of FACULTY RESEARCHES.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of MEMORANDUM OF UNDERSTANDING ALLIANCE SOFTWARE116.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 06-09-23 LETTER-OF-COMMITMENT035.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 10-31-20 Formal Invitation Letter to 2020 NHEC Summit.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of REPRESENTATIVE FOR FACE IT003.pdf.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of page 3 Class Status 1st semester 2019-2020.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 08-01-19 Arrival Information.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of full scale 008.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of NESO TECHNICAL 068.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 6-7-23 International Project-Based Learning Program (IPBL) 004.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 03-09-20 Excuse letter of all ROTC students - 1.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of 17-22 IT Services 2019019047.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of Digitization in nursing informatics in collaboration with other department045.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
# Deleted Copy of full scale 009.jpg.txt from /Users/garfieldgreglim/Documents/JQ/Knowledgebase 2/final_classified_txts/irrelevant
